# %%
from pathlib import Path
import pandas as pd
import numpy as np
import sys
ROOT = Path.cwd().parent.parent
sys.path.append(str(ROOT))
from src.loading_data.load_data import get_clean_2022, get_master_clustering_input, get_raw_2022_data

# %%
df = get_raw_2022_data()

# %%
df.columns
# Out:
# Index(['serial', 'Motiva_POP', 'motivd_POP', 'inclus_a', 'inclus_b',
#        'inclus_c', 'anxious', 'comm1', 'comm2', 'happy', 'indev', 'indevtry',
#        'lone', 'worthw'],
#       dtype='str')

# %%
df['comm2'].value_counts()
# Out:
# comm2
# 3.0    40371
# 2.0     8030
# 4.0     6089
# 1.0     2280
# Name: count, dtype: int64
