# %%
import pandas as pd
import numpy as np
from pathlib import Path
import sys
ROOT = Path.cwd().parent.parent
sys.path.append(str(ROOT))
from src.loading_data.data_catalogue import DataCatalogue
from src.loading_data.load_data import get_master_clustering_input

# %%
df = pd.read_csv(r'C:\Users\fergu\Documents\GitHub\london_sport2\data\master_data\2016_to_2023_clustering_output_data.csv')
df['LCA_Class'].value_counts()
# Out:
# LCA_Class
# 2     7779
# 7     5288
# 3     5166
# 20    5100
# 17    5010
# 15    4998
# 11    4387
# 5     3832
# 10    3807
# 12    3590
# 19    3508
# 22    3011
# 4     2943
# 21    2879
# 1     2767
# 23    2696
# 16    2640
# 26    2396
# 9     2240
# 0     2028
# 6     1662
# 14    1645
# 8     1600
# 13    1440
# 25    1350
# 24    1331
# 18     566
# Name: count, dtype: int64
