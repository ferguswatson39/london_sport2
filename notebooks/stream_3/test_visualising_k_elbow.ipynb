# %%
import sys
from pathlib import Path
import matplotlib.pyplot as plt
ROOT = Path.cwd().parent.parent
sys.path.append(str(ROOT))
import pickle
import pandas as pd
from src.stream_3.gen_kprototypes_clus import GenerateKPrototypes2

# %%
path = r'C:\Users\fergu\Documents\GitHub\london_sport2\src\stream_3\k_prototypes\GenerateKPrototypes2.sav'
with open(path, 'rb') as file:
    k_proto = pickle.load(file)

# %%
costs = k_proto.get_costs()
plt.plot(range(2,80), costs)

# %%
input_path = r'C:\Users\fergu\Documents\GitHub\london_sport2\data\master_data\2016_to_2023_clustering_input_data.csv'
output_path = r'C:\Users\fergu\Documents\GitHub\london_sport2\data\master_data\2016_to_2023_clustering_output_data.csv'
input_df = pd.read_csv(input_path)
output_df = pd.read_csv(output_path)

# %%
print(input_df.shape)
print(output_df.shape)
# Out:
# (85659, 14)
# (85659, 65)
