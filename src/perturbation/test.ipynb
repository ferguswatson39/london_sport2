# %%
from pathlib import Path
import pandas as pd
import numpy as np
import sys
ROOT = Path.cwd().parent.parent
sys.path.append(str(ROOT))
from src.loading_data.load_data import get_master_2022_data, get_raw_2022_data

# %%
path = r'C:\Users\fergu\Documents\GitHub\london_sport2\data\master_data\2016_to_2023_master_clustering_data_set.csv'
df = pd.read_csv(path)
df = df[df['year'] == '2022/23']

# %%
len(df)
# Out:
# 16748

# %%
df = df[df['LCA_Class'].notna()]

# %%
len(df)
# Out:
# 12555

# %%
x = df.isna().sum()

# %%
x
# Out:
# serial                       0
# year                         0
# wt_final                     0
# month                        0
# LCA_Class                    0
#                          ...
# ACT7GR_ALL               10155
# ACT7GR_SPORTCOUNT_A01     9925
# Number_Activities            0
# CLUB_SPORTCOUNT_A01          0
# Number_Club                  0
# Length: 62, dtype: int64

# %%
for idx, i in enumerate(x):
    if i > 0:
        print(x.index[idx])
# Out:
# NSSEC5
# health
# comm1
# anxious
# happy
# lifesat
# lone
# DVBMI
# FruitVegPor
# READYAB1_POP
# CULFRQ_1_9_POP
# VolAny
# VolCnt
# VolDur
# VolFrqB_Pop
# volint1
# volint2
# volint3
# volint4
# volint5
# volint6
# volint7
# MEMS7_IN_SPORTCOUNT_A01
# MEMS7_OUT_SPORTCOUNT_A01
# ACT7GR_ALL
# ACT7GR_SPORTCOUNT_A01

# %%
# raw = get_raw_2022_data()

# %%
len(raw)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 len(raw)
#
# NameError: name 'raw' is not defined
