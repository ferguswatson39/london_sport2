# %%
from prepare_time_boroughs import prepare_monthly_boroughs
from sarima_forecast import tune_sarima
df_month = prepare_monthly_boroughs()
# Out:
# PREPARING MONTHLY DATA...
# COMPLETE

# %%
df_month_tuned = tune_sarima(df_month, 72, 12)
print(df_month_tuned[['borough', 'mape']].to_string())
# Out:
# -------------------------
# ----- TUNING SARIMA -----
# -------------------------
#   0%|          | 0/32 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_month_tuned = tune_sarima(df_month, 72, 12)
#       2 print(df_month_tuned[['borough', 'mape']].to_string())
#
# File ~/Library/CloudStorage/GoogleDrive-jeverer@gmail.com/My Drive/London Sport/london_sport2/src/stream_1/forecasting/sarima_forecast.py:59, in tune_sarima(df, t_train_cutoff, forecast_steps)
#      56 df_borough_train = df_borough[df_borough['t'] < t_train_cutoff]['MEMS7_ALL']
#      57 df_borough_test = df_borough[df_borough['t'] >= t_train_cutoff]['MEMS7_ALL']
# ---> 59 arima_model = auto_arima(df_borough_train, seasonal=True, m=seasonal_period, stepwise=True, suppress_warnings=True, error_action='ignore')
# ...
